# %%
import sys
import os
from time import time

DATAPATH = '/Users/balthasar/Google Drive/MTL_data/nypost/'
sys.path.append(DATAPATH)
sys.path.append('../')

from src.util import count_lines_many, data_from_many, unpack, bunch_paragraphs

datafiles = [DATAPATH + file for file in os.listdir(DATAPATH)]
print("Number of entries: %i" % (count_lines_many(datafiles)))
# Out:
# Number of entries: 757217

# %%
data = data_from_many(datafiles)
url, html = unpack(next(data))

import re 
from bs4 import BeautifulSoup

def get_paragraphs(html):
    soup = BeautifulSoup(html,'html.parser')
    paragraphs = [tag.get_text() for tag in [soup.findAll('title')[0]]+soup.findAll('description')[1:]+soup.findAll(type='html')+soup.findAll('p')]
    if len(paragraphs) != 0:
        return paragraphs
    else:
        return 'NOCONTENT'

label_re = re.compile('(?<="section":")[a-zA-Z0-9]*(?=")|(?<="articleSection":")[a-zA-Z0-9]*(?=")')
def get_label(html):
    try:
        return label_re.search(html).group()
    except:
        return "NOLABEL"
    
print(get_label(html))
print(url)
get_paragraphs(html)
# Out:
# NOLABEL
# https://nypost.com/2012/07/08/years-of-cro-mags-dischord-climaxes-in-e-village-stabbing-rampage/feed/
# ['Years of Cro-Mags dis‘chord’ climaxes in E. Village stabbing rampage',
#  'What a punk! Former Cro-Mags bassist Harley Flanagan entered the rock ’n’ roll feud Hall of Fame Friday night when he showed up at the CBGB Festival at Webster Hall with a hunting knife — and his own sharp teeth. “They think they’re going to play my f&#8211;king music that I helped write?” the berserk...',
#  '08.1n016.CroMags2--300x300.jpg',
#  '08.1n016.CroMags1--300x300.jpg']

# %%
BeautifulSoup(html)
# Out:
# /Users/balthasar/.virtualenvs/news_preprocessor/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# <!DOCTYPE html>
# <html amp="">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,minimal-ui" name="viewport"/>
# <meta content="googleanalytics" name="amp-google-client-id-api"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon.png" rel="apple-touch-icon"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/favicon-nypost/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/wp-content/themes/vip/nypost-2016/static/nypost-manifest.json" rel="manifest"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type"/>
# <meta content="Rodale CEO aims to expand e-commerce operation" property="og:title"/>
# <meta content="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/" property="og:url"/>
# <meta content="Scott Schulman, the ex-president of Rodale, was said to have clashed with Chairwoman and Chief Executive Maria Rodale over how much money to pump into the company’s fledgling e-commerce site. Rodal…" property="og:description"/>
# <meta content="2015-10-23T02:54:38+00:00" property="article:published_time"/>
# <meta content="2015-10-23T02:54:38+00:00" property="article:modified_time"/>
# <meta content="New York Post" property="og:site_name"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="@nypost" name="twitter:site"/>
# <meta content="Rodale CEO aims to expand e-commerce operation" name="twitter:text:title"/>
# <meta content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=664&amp;h=441&amp;crop=1" name="twitter:image:src"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@media_ink" name="twitter:creator"/>
# <meta content="https://www.facebook.com/nypost" property="article:publisher"/>
# <meta content="Rodale CEO aims to expand e-commerce operation" name="twitter:title"/>
# <meta content="Scott Schulman, the ex-president of Rodale, was said to have clashed with Chairwoman and Chief Executive Maria Rodale over how much money to pump into the company’s fledgling e-commerce site.
# Rodale" name="twitter:description"/>
# <meta content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=664&amp;h=441&amp;crop=1" name="twitter:image"/>
# <meta content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=1200" property="og:image"/>
# <meta content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=1200" property="og:image:secure_url"/>
# <!-- End Jetpack Open Graph Tags -->
# <meta content='{"post_id":"nypost-9909409"}' name="parsely-metadata"/>
# <title>Rodale CEO aims to expand e-commerce operation</title>
# <link href="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/" rel="canonical"/>
# <script async="" custom-element="amp-analytics" src="https://cdn.ampproject.org/v0/amp-analytics-0.1.js"></script><script async="" custom-element="amp-iframe" src="https://cdn.ampproject.org/v0/amp-iframe-0.1.js"></script><script async="" custom-element="amp-ad" src="https://cdn.ampproject.org/v0/amp-ad-0.1.js"></script><script async="" custom-element="amp-sticky-ad" src="https://cdn.ampproject.org/v0/amp-sticky-ad-1.0.js"></script><script async="" custom-element="amp-lightbox" src="https://cdn.ampproject.org/v0/amp-lightbox-0.1.js"></script><script async="" custom-element="amp-sidebar" src="https://cdn.ampproject.org/v0/amp-sidebar-0.1.js"></script><script async="" src="https://cdn.ampproject.org/v0.js"></script><link href="https://fonts.googleapis.com/css?family=Merriweather:400,400italic,700,700italic" rel="stylesheet"/> <script type="application/ld+json">{"@context":"http:\/\/schema.org","publisher":{"@type":"Organization","name":"New York Post","sameAs":"https:\/\/nypost.com","logo":{"@type":"ImageObject","url":"https:\/\/s2.wp.com\/wp-content\/themes\/vip\/nypost-2016\/static\/images\/logo-nypost.png","height":60,"width":404}},"headline":"Rodale CEO aims to expand e-commerce operation","url":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/","thumbnailUrl":"https:\/\/thenypost.files.wordpress.com\/2015\/10\/gettyimages-92659975.jpg?quality=90&strip=all","image":{"@type":"ImageObject","url":"https:\/\/thenypost.files.wordpress.com\/2015\/10\/gettyimages-92659975.jpg?quality=90&strip=all","width":1024,"height":683},"mainEntityOfPage":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/","@type":"NewsArticle","dateCreated":"2015-10-23T02:54:38Z","datePublished":"2015-10-23T02:54:38Z","dateModified":"2015-10-23T02:54:38Z","articleSection":"media","creator":["Keith J. Kelly"],"author":[{"@type":"Person","name":"Keith J. Kelly"}],"keywords":["media ink","rodale inc.","\/article"]}</script>
# <meta content="AMP Plugin v0.6.2" name="generator"/> <link href="https://use.typekit.net/lui2fni.css" rel="stylesheet"/>
# <style amp-boilerplate="">body{-webkit-animation:-amp-start 8s steps(1,end) 0s 1 normal both;-moz-animation:-amp-start 8s steps(1,end) 0s 1 normal both;-ms-animation:-amp-start 8s steps(1,end) 0s 1 normal both;animation:-amp-start 8s steps(1,end) 0s 1 normal both}@-webkit-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@-moz-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@-ms-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@-o-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}</style><noscript><style amp-boilerplate="">body{-webkit-animation:none;-moz-animation:none;-ms-animation:none;animation:none}</style></noscript>
# <style amp-custom="">
# 	.share-count{font-size:14px;font-size:.875rem;padding:8px;background-color:#c33;color:#fff;float:right;font-family:futura-pt,sans-serif;font-weight:700}amp-img.alignright{float:right;margin:0 0 1em 1em}amp-img.alignleft{float:left;margin:0 1em 1em 0}amp-img.aligncenter{display:block;margin-left:auto;margin-right:auto}.alignright{float:right}.alignleft{float:left}.aligncenter{display:block;margin-left:auto;margin-right:auto}.wp-caption.alignleft{margin-right:1em}.wp-caption.alignright{margin-left:1em}.amp-wp-enforced-sizes{max-width:100%}body{font-size:16px;line-height:1.5;background:#fff;color:#2a2a2a;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.content,body{font-weight:400}.content{padding:10px;overflow-wrap:break-word;word-wrap:break-word;margin:106px auto 0;max-width:978px}figure,ol,p,ul{margin:0 0 24px}a,a:visited{text-decoration:none}header{position:fixed;top:0;width:100%;z-index:1000}.title-bar{-webkit-align-items:center;-ms-flex-align:center;align-items:center;display:-webkit-flex;display:-ms-flexbox;display:flex;height:50px;line-height:0}.header__logo{margin:0 auto}.header__logo svg{height:33px}figure{display:table}.wp-caption-text{padding:6px 0;caption-side:bottom;font-size:.875rem;line-height:normal}.alignleft,.alignright{max-width:100%}.alignleft .wp-caption-text,.alignright .wp-caption-text{display:table-caption}.credit{display:block;font-size:12px;color:#bfbfbf}.featured-image img,.wp-caption img{margin-bottom:3px}.featured-image{margin-bottom:24px}.featured-image .wp-caption-text{display:block}amp-brightcove,amp-iframe{margin-bottom:24px}amp-iframe,amp-instagram,amp-vine,amp-youtube{background:#fff}amp-instagram{border:0;margin:1px;max-width:96%;width:calc(100% - 2px);border-radius:4px;box-shadow:0 0 1px 0 rgba(0,0,0,.498039),0 1px 10px 0 rgba(0,0,0,.14902);display:block;padding:0}.sharedaddy{display:none}#page-footer{text-align:center;font-size:10px}#page-footer .content{color:#000;margin:0}.section-tag{display:inline-block;margin:0 0 10px;padding:3px 5px}.section-tag,.tag-list{text-transform:uppercase}.tag-list{font-weight:800;font-size:12px;line-height:12px;margin-bottom:30px}.amp-ad-container{text-align:center;margin:0 0 24px}.amp-ad-container iframe{max-width:300px}.in-line-column.wp-caption.alignleft{margin-right:0}.inline-tag{display:none}.sponsor{background-color:#f6f6f6;border-bottom:4px solid #2a2a2a;font-weight:700;margin:5px 0 24px;padding:20px}.sponsor p{margin-bottom:0}.list-image-wrapper img{margin-bottom:3px}.article-list-wrapper .number{float:left;font-size:14px;line-height:14px;margin:2px 3px 0 0;padding:2px 4px 3px 0;text-align:right;min-width:20px;white-space:nowrap}.article-list-wrapper .number:after{content:"."}.article-list-wrapper .article-list-content h3{color:#c33;font-size:20px;font-weight:400;line-height:20px;margin-bottom:0}.article-list-wrapper .article-list-content h4{font-size:15px;line-height:18px;margin:0}.article-list-wrapper .list-image-wrapper{margin-bottom:29px;margin-top:20px;font-size:14px}.modal-trigger{display:none}.amp-carousel-button-next{right:0}.amp-carousel-button-prev{left:0}.carousel__slides{height:100%}.lightbox__gallery{background-color:#000}.lightbox__gallery .wp-caption-text{background:rgba(0,0,0,.5);border:none;box-sizing:border-box;caption-side:bottom;color:#fff;font-size:.875rem;line-height:normal;overflow:scroll;padding:.375rem;width:100%}.lightbox__gallery .container__caption[data-orientation=landscape] .wp-caption-text{max-height:calc(100vh - 66.66666666666667vw)}.lightbox__gallery .container__caption[data-orientation=square] .wp-caption-text{max-height:calc(100vh - 100vw)}.lightbox__gallery .container__caption[data-orientation=portrait] .wp-caption-text{bottom:0;max-height:6.25rem;position:absolute}.button__close:after{background-image:url(data:image/svg+xml;base64,...);background-repeat:no-repeat;content:"";display:inline-block;position:absolute;top:.625rem;right:.625rem;z-index:1;height:1.5rem;padding-bottom:.625rem;width:1.5r ...
# </head>
# <body class="google-amp">
# <amp-sidebar id="navigation" layout="nodisplay">
# <div class="menu-main-menu-container"><ul class="menu" id="menu-main-menu"><li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612774" id="menu-item-1612774"><a data-vars-menu-item-title="News" href="/news/">News</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612773" id="menu-item-1612773"><a data-vars-menu-item-title="Metro" href="/metro/">Metro</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1612779" id="menu-item-1612779"><a data-vars-menu-item-title="Page Six" href="https://pagesix.com/">Page Six</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612777" id="menu-item-1612777"><a data-vars-menu-item-title="Sports" href="/sports/">Sports</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612768" id="menu-item-1612768"><a data-vars-menu-item-title="Business" href="/business/">Business</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612775" id="menu-item-1612775"><a data-vars-menu-item-title="Opinion" href="/opinion/">Opinion</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612769" id="menu-item-1612769"><a data-vars-menu-item-title="Entertainment" href="/entertainment/">Entertainment</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1617339" id="menu-item-1617339"><a data-vars-menu-item-title="Fashion" href="/fashion/">Fashion</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612771" id="menu-item-1612771"><a data-vars-menu-item-title="Living" href="/living/">Living</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section current-article-ancestor current-menu-parent current-article-parent menu-item-1612772" id="menu-item-1612772"><a data-vars-menu-item-title="Media" href="/media/">Media</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1612778" id="menu-item-1612778"><a data-vars-menu-item-title="Tech" href="/tech/">Tech</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-1615324" id="menu-item-1615324"><a data-vars-menu-item-title="Real Estate" href="/real-estate/">Real Estate</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-9914299" id="menu-item-9914299"><a data-vars-menu-item-title="Sub Menu 1" href="#">Sub Menu 1</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-9914303" id="menu-item-9914303"><a data-vars-menu-item-title="Video" href="/video/">Video</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-section menu-item-9914301" id="menu-item-9914301"><a data-vars-menu-item-title="Photos" href="/photos/">Photos</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7962507" id="menu-item-7962507"><a data-vars-menu-item-title="Covers" href="https://nypost.com/covers">Covers</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7962530" id="menu-item-7962530"><a data-vars-menu-item-title="Columnists" href="https://nypost.com/columnists/">Columnists</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-7962521" id="menu-item-7962521"><a data-vars-menu-item-title="Horoscopes" href="https://nypost.com/horoscopes/">Horoscopes</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-10775960" id="menu-item-10775960"><a data-vars-menu-item-title="Email Newsletters" href="https://email.nypost.com/">Email Newsletters</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-
# </nav>
# <ul class="social-share nypost">
# <li id="share-facebook">
# <a class="share-facebook sd-button share-icon" href="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/?share=facebook" rel="nofollow" target="_blank" title="Share on Facebook"><span>Facebook</span></a> </li>
# <li id="share-twitter">
# <a class="share-twitter sd-button share-icon" href="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/?share=twitter" rel="nofollow" target="_blank" title="Click to share on Twitter"><span>Twitter</span></a> </li>
# <li id="share-google-plus-1">
# <a class="share-google-plus-1 sd-button share-icon" href="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/?share=google-plus-1" rel="nofollow" target="_blank" title="Click to share on Google+"><span>Google</span></a> </li>
# <li id="share-nyp-messenger">
# <a class="share-messenger sd-button share-icon" href="fb-messenger://share/?link=http://nyp.st/1LqJ9Of&amp;appId=823934954307605" id="sharing-messenger-9909409" rel="nofollow" title="Click to share on Facebook Messenger"><span>Facebook Messenger</span></a> </li>
# <li id="share-whatsapp">
# <a class="share-whatsapp sd-button share-icon" href="whatsapp://send?text=Rodale%20CEO%20aims%20to%20expand%20e-commerce%20operation%20http://nyp.st/1LqJ9Of" id="sharing-messenger-9909409" rel="nofollow" title="Click to share on Whatsapp"><span>WhatsApp</span></a> </li>
# <li id="share-email">
# <a class="share-email sd-button share-icon no-text" href="mailto:?subject=New%20York%20Post:%20Rodale%20CEO%20aims%20to%20expand%20e-commerce%20operation&amp;body=I%20thought%20you%27d%20be%20interested%20in%20this%20story%20from%20the%20New%20York%20Post.%0A%0ARodale%20CEO%20aims%20to%20expand%20e-commerce%20operation%0Ahttp%3A%2F%2Fnyp.st%2F1LqJ9Of%0A%0AFor%20more%20on%20the%20New%20York%20Post%20and%20to%20download%20our%20apps%2C%20visit%20https%3A%2F%2Fnypost.com" rel="nofollow" title="Click to email this to a friend"></a>
# </li>
# <li id="share-nyp-post-url" on="tap:share-url-modal" role="button" tabindex="0">
# <a class="share-nyp-post-url sd-button share-icon no-text" rel="nofollow" title="Click to copy URL"></a>
# </li>
# </ul>
# </header>
# <div class="content">
# <p class="section-tag">
# <a class="" href="/media/">Media</a>
# </p>
# <h1 class="title">Rodale CEO aims to expand e-commerce operation</h1>
# <p class="no-description byline" id="author-byline">By <a class="keith-j-kelly" href="https://nypost.com/author/keith-j-kelly/">Keith J. Kelly</a></p><p class="byline-date">
# 	October 22, 2015 | 10:54pm</p>
# <div class="featured-image" id="9909409"><amp-img alt="" class="attachment-978x999 size-978x999 amp-wp-enforced-sizes" height="652" sizes="(min-width: 978px) 978px, 100vw" src="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=978" width="978"></amp-img><div class="wp-caption-text featured">
# 				Chairman and CEO of Rodale Inc. Maria Rodale
# 				<span class="credit">Getty Images</span>
# </div></div><p>Scott Schulman, the ex-president of Rodale, was said to have clashed with Chairwoman and Chief Executive Maria Rodale over how much money to pump into the company’s fledgling e-commerce site.</p><p>Rodale is the third generation to head the family-owned company.</p><p>She has two pet projects, e-commerce and <a href="https://nypost.com/2014/08/23/rodale-revamps-organic-gardening-to-healthy-lifestyle-magazine/">the conversion of the earthy Organic Gardening into the lifestyle title Rodale’s Organic Life</a>.</p><p>Schulman was supportive of the mag, which debuted in February, since the magazine had a subscription list. Its first-year investment is believed to be $5 million, and ad pages are up about 40 percent.</p><p>But insiders said he felt e-commerce, which was costing millions, was draining money that would have been better spent elsewhere. Developing its digital premium content sites was his first choice for funding.</p><div class="amp-ad-container"><amp-ad data-slot="/5850/post.mobileamp/inline_1/media/stories" height="250" json='{"useSameDomainRenderingUntilDeprecated":1}' type="doubleclick" width="300"></amp-ad></div><p>Maria Rodale has been pushing to use the family name to broaden beyond publishing and is calling the firm a “healthy living company.”</p><p>But insiders said she is doing e-commerce in a very costly way, by taking title to the goods that are being sold.</p><p>That requires a whole new level of investment in warehousing and shipping costs.</p><p>Some of the brand managers felt that resources were being diverted from individual brands, which include Men’s Health, Prevention and Runner’s World.</p><p>Sources also said Schulman was blindsided by the decision not to renew his two-year contract.</p><p>“He thought he was going to a sit-down to talk about a contract extension,” said one source.</p><p>Instead, the company said on Friday, Schulman and Rodale had reached a mutual decision that he would step down.</p><p><amp-sticky-ad layout="nodisplay"><amp-ad data-slot="/5850/post.mobileamp/bottom/media/stories" height="50" type="doubleclick" width="320"></amp-ad></amp-sticky-ad></p>
# <div class="tag-list">
# <span>Filed under</span>
# <a href="https://nypost.com/tag/media-ink/" rel="tag">media ink</a>
# <span class="sep">, </span>
# <a href="https://nypost.com/tag/rodale-inc/" rel="tag">rodale inc.</a>
# </div>
# <amp-embed data-ampurl="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/amp/" data-htmlurl="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/" data-widgetids="AMP_1" height="100" layout="responsive" type="outbrain" width="100">
# </amp-embed>
# <amp-embed data-zergid="57183" height="100" heights="(max-width:370px) 245%, (max-width:450px) 220%, (max-width:550px) 190%, (max-width:600px) 175%, (max-width:645px) 170%, 170%" layout="responsive" type="zergnet" width="780">
# </amp-embed>
# <div class="trending-now__feature">
# <h2 class="widgettitle">trending now<h4 class="widget-subtitle no-subtitle"></h4></h2>
# <div class="image-layout show">
# <div class="trending-now__feature feature">
# <a href="https://pagesix.com/2018/05/02/vanessa-trump-is-a-marinara-sauce-heiress/">
# <amp-img alt="Rodale CEO aims to expand e-commerce operation" class="list-item-image" height="200" layout="responsive" src="https://nyppagesix.files.wordpress.com/2018/05/vanessa-trump-raos.jpg?quality=90&amp;strip=all&amp;w=300&amp;h=200&amp;crop=1" width="300">
# </amp-img>
# Vanessa Trump is a marinara sauce heiress					</a>
# </div>
# <div class="trending-now__feature feature">
# <a href="https://nypost.com/2018/05/02/southwest-airlines-flight-makes-emergency-landing-due-to-broken-window/">
# <amp-img alt="Rodale CEO aims to expand e-commerce operation" class="list-item-image" height="200" layout="responsive" src="https://thenypost.files.wordpress.com/2018/05/180502-southwest-airlines-broken-window-index.jpg?quality=90&amp;strip=all&amp;w=300&amp;h=200&amp;crop=1" width="300">
# </amp-img>
# Southwest flight lands after window breaks, airline says 'It's NBD'					</a>
# </div>
# <div class="trending-now__feature feature">
# <a href="https://pagesix.com/2018/05/03/camille-cosby-shares-blistering-statement-calling-for-prosecutor-probe/">
# <amp-img alt="Rodale CEO aims to expand e-commerce operation" class="list-item-image" height="200" layout="responsive" src="https://nyppagesix.files.wordpress.com/2018/05/gettyimages-695399796.jpg?quality=90&amp;strip=all&amp;w=300&amp;h=200&amp;crop=1" width="300">
# </amp-img>
# Camille Cosby shares blistering statement calling for prosecutor probe					</a>
# </div>
# <div class="trending-now__feature feature">
# <a href="https://pagesix.com/2018/05/02/msnbcs-donny-deutsch-gets-into-scuffle-at-the-polo-bar/">
# <amp-img alt="Rodale CEO aims to expand e-commerce operation" class="list-item-image" height="200" layout="responsive" src="https://nyppagesix.files.wordpress.com/2018/05/donny-deutch.jpg?quality=90&amp;strip=all&amp;w=300&amp;h=200&amp;crop=1" width="300">
# </amp-img>
# MSNBC's Donny Deutsch gets into scuffle at the Polo Bar					</a>
# </div>
# <div class="trending-now__feature feature">
# <a href="https://nypost.com/2018/05/03/driver-who-fatally-struck-tony-winners-daughter-infant-indicted-on-multiple-charges/">
# <amp-img alt="Rodale CEO aims to expand e-commerce operation" class="list-item-image" height="200" layout="responsive" src="https://thenypost.files.wordpress.com/2018/05/180503-dorothy-bruns-arrest-feature-image.jpg?quality=90&amp;strip=all&amp;w=300&amp;h=200&amp;crop=1" width="300">
# </amp-img>
# Driver who ran over Tony winner's daughter hit with slew of charges					</a>
# </div>
# <div class="trending-now__feature feature">
# <a href="https://nypost.com/2018/05/02/a-long-term-degrom-injury-likely-would-wreck-mets-season/">
# <amp-img alt="Rodale CEO aims to expand e-commerce operation" class="list-item-image" height="200" layout="responsive" src="https://thenypost.files.wordpress.com/2018/05/degrom-4.jpg?quality=90&amp;strip=all&amp;w=300&amp;h=200&amp;crop=1" width="300">
# </amp-img>
# Mets' season may have ended after deGrom pitched through pain					</a>
# </div>
# </div>
# </div>
# <amp-lightbox id="share-url-modal" layout="nodisplay">
# <div class="overlay" id="share-url-overlay" on="tap:share-url-modal.close" role="button" tabindex="0">
# <div id="share-url-inner" on="tap:share-url-modal" role="button" tabindex="0">
# <div class="close-share-modal" on="tap:share-url-modal.close" role="button" tabindex="0"></div>
# <div class="copy-url">http://nyp.st/1LqJ9Of</div>
# <span class="copy-message">Copy the URL to share</span>
# </div>
# </div>
# </amp-lightbox>
# </div>
# <footer id="page-footer">
# <div class="content">
com/?utm_source=vip_powered_wpcom&amp;utm_medium=web&amp;utm_campaign=VIP%20Footer%20Credit&amp;utm_term=nypost.com" rel="generator nofollow"><amp-img alt="Powered by WordPress.com VIP" height="26" src="https://s0.wp.com/wp-content/themes/vip/plugins/vip-do-not-include-on-wpcom/vip-powered-wpcom/images/vip-powered-dark-small.png" width="187"></amp-img></a>
# </div>
# </footer>
# <amp-analytics id="analytics1" type="googleanalytics">
# <script type="application/json">
# 			{"vars":{"account":"UA-3922003-6"},"triggers":{"trackPageviewWithCustom":{"on":"visible","request":"pageview","vars":[],"extraUrlParams":{"campaignName":"${queryParam(utm_campaign)}","campaignSource":"${queryParam(utm_source)}","campaignMedium":"${queryParam(utm_medium)}"}},"trackClickOnHeader":{"on":"click","selector":".title-bar a","request":"event","vars":{"eventCategory":"AMP Header","eventAction":"nypost.com"}},"trackClickOnFooter":{"on":"click","selector":"#page-footer a","request":"event","vars":{"eventCategory":"AMP Footer","eventAction":"nypost.com"}},"trackCarouselLoad":{"on":"ini-load","request":"pageview","selector":"amp-carousel","extraUrlParams":{"cd29":1,"cd1":"AMP Article Gallery View","cg1":"AMP Article Gallery View"}},"trackCarouselChange":{"on":"amp-carousel-change","request":"pageview","extraUrlParams":{"cd1":"AMP Article Gallery View","cg1":"AMP Article Gallery View"}},"trackClickOnMainNav":{"on":"click","selector":"#menu-main-menu a","request":"event","vars":{"eventCategory":"Top Nav","eventAction":"${menuItemTitle}"}},"trackClickOnSharefacebook":{"on":"click","selector":"a.share-facebook","request":"social","vars":{"socialNetwork":"facebook","socialAction":"AMP Share","socialTarget":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/"}},"trackClickOnSharetwitter":{"on":"click","selector":"a.share-twitter","request":"social","vars":{"socialNetwork":"twitter","socialAction":"AMP Share","socialTarget":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/"}},"trackClickOnSharegoogle-plus-1":{"on":"click","selector":"a.share-googleplus1","request":"social","vars":{"socialNetwork":"google-plus-1","socialAction":"AMP Share","socialTarget":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/"}},"trackClickOnSharemessenger":{"on":"click","selector":"a.share-nyp-messenger","request":"social","vars":{"socialNetwork":"messenger","socialAction":"AMP Share","socialTarget":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/"}},"trackClickOnSharewhatsapp":{"on":"click","selector":"a.share-whatsapp","request":"social","vars":{"socialNetwork":"whatsapp","socialAction":"AMP Share","socialTarget":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/"}},"trackClickOnShareemail":{"on":"click","selector":"a.share-email","request":"social","vars":{"socialNetwork":"email","socialAction":"AMP Share","socialTarget":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/"}},"trackClickOnShareurl":{"on":"click","selector":"a.share-nyp-post-url","request":"social","vars":{"socialNetwork":"url","socialAction":"AMP Share","socialTarget":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/"}}},"extraUrlParams":{"dimension3":"media ink,rodale inc.","dimension2":"Keith J. Kelly","dimension1":"AMP article","dimension5":"standard","dimension6":"Rodale CEO aims to expand e-commerce operation","dimension7":"","dimension12":"Rodale CEO aims to expand e-commerce operation","dimension9":"2015-10-22","dimension10":"22:54","dimension11":9909409,"dimension31":"https:\/\/nypost.com\/2015\/10\/22\/rodale-ceo-aims-to-expand-e-commerce-operation\/","dimension4":"media","dimension15":"media ink","dimension16":260,"dimension17":"no","dimension8":"AMP","dimension29":"${toSlide}","dimension40":"no","contentGroup1":"AMP article","contentGroup2":"media","contentGroup3":"nypost.com"},"extraUrlParamsReplaceMap":{"contentGroup":"cg"}}			</script>
# </amp-analytics>
# <amp-analytics type="parsely">
# <script type="application/json">
# 			{
# 				"vars": {
# 					"apikey": "nypost.com"				}
# 			}
# 			</script>
# </amp-analytics>
# <amp-analytics type="quantcast">
# <script type="application/json">
# 				{
# 					"vars": {"pcode":"p-fx75g3JszSBqD","labels":["AMPProject","media"]}				}
# 				</script>
# </amp-analytics>
# <amp-analytics type="comscore">
# <script type="application/json">
# 			{
# 				"vars": {
# 					"c2": "6390601"
# 				}
# 			}
# 			</script>
# </amp-analytics>
# <amp-analytics type="piano">
# <script type="application/json">
# 			{
# 				"vars": {
# 					"aid": "MH9NDnRj2b",
# 					"contentCreated": "2015-10-22T22:54:38+00:00",
# 					"contentSection": "media",
# 					"contentAuthor": "Keith J. Kelly",
# 					"tags": ["article","nypost","media ink","rodale inc."]				},
# 				"triggers": {
# 					"trackPageview": {
# 						"on": "visible",
# 						"request": "pageview"
# 					}
# 				}
# 			}
# 			</script>
# </amp-analytics>
# <amp-pixel src="https://pixel.wp.com/b.gif?rand=RANDOM&amp;host=nypost.com&amp;ref=DOCUMENT_REFERRER&amp;amp=1&amp;blog=56757169&amp;v=wpcom&amp;tz=-4&amp;user_id=0&amp;post=9909409&amp;subd=thenypost"></amp-pixel>
# <amp-pixel src="https://pixel.wp.com/b.gif?rand=RANDOM&amp;v=wpcom-no-pv&amp;crypt=UE40eW5QN0p8M2Y%2FRE1BNmNJfGhxNCVxUDExYmtib2E%2FSzdEJm0lUEtbdFU0fFk4cHZvcUFrZT90Tn4yQm1%2BR3NyNTdhJitIV3pvNTdrYm40UDdDc3FnfklhcWR4amlENGs5X1AyUlVIan5rZnZkemFmUEtwUCtGSWh%2BUUZ4cU5Hb345Ly9SM1Y4dDJuL0Y9N0hDVzgvcz1JK0J8dF1BVnlFNDhTVDJPLV9rW01wKyUtbHIuZ1ovWUMsUGw4QkVObXQ5aHNBc2hGel9KX2J1LmxzMjBsRVJmbUFGflBFR0MlSWNBM1pOSCxGVA%3D%3D"></amp-pixel>
# </body>
# </html>

# %%
url
# Out:
# 'https://nypost.com/2013/09/18/japan-high-school-coach-repeatedly-slaps-player-in-face/feed/'

# %%
label_re
# Out:
# re.compile(r'(?<="section":")[a-zA-Z0-9]*(?=",)', re.UNICODE)

# %%
label_re.search('adads').group()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-5df483765af3> in <module>()
# ----> 1 label_re.search('adads').group()
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
html
# Out:
# '<!doctype html>\n<html amp>\n<head>\n\t<meta charset="utf-8">\n\t<meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,minimal-ui">\n\t<meta name="amp-google-client-id-api" content="googleanalytics">\n\t\t<link rel="apple-touch-icon" href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon.png" />\n\t\t\t\t\t\t\t<link rel="apple-touch-icon" sizes="57x57" href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon-57x57.png" />\n\t\t\t\t\t<link rel="apple-touch-icon" sizes="114x114" href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon-114x114.png" />\n\t\t\t\t\t<link rel="apple-touch-icon" sizes="144x144" href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/apple-icons/nypost/apple-icon-144x144.png" />\n\t\t\t\t<link rel="shortcut icon" type="image/x-icon" href="https://s2.wp.com/wp-content/themes/vip/nypost-2016/static/images/favicon-nypost/favicon.ico" />\n\n\t\t\t<link rel="manifest" href="/wp-content/themes/vip/nypost-2016/static/nypost-manifest.json">\n\t\n\t\n<!-- Jetpack Open Graph Tags -->\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Rodale CEO aims to expand e-commerce operation" />\n<meta property="og:url" content="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/" />\n<meta property="og:description" content="Scott Schulman, the ex-president of Rodale, was said to have clashed with Chairwoman and Chief Executive Maria Rodale over how much money to pump into the company’s fledgling e-commerce site. Rodal…" />\n<meta property="article:published_time" content="2015-10-23T02:54:38+00:00" />\n<meta property="article:modified_time" content="2015-10-23T02:54:38+00:00" />\n<meta property="og:site_name" content="New York Post" />\n<meta property="og:image:width" content="1200" />\n<meta property="og:image:height" content="800" />\n<meta property="og:locale" content="en_US" />\n<meta name="twitter:site" content="@nypost" />\n<meta name="twitter:text:title" content="Rodale CEO aims to expand e-commerce operation" />\n<meta name="twitter:image:src" content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=664&amp;h=441&amp;crop=1" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:creator" content="@media_ink" />\n<meta property="article:publisher" content="https://www.facebook.com/nypost" />\n<meta name="twitter:title" content="Rodale CEO aims to expand e-commerce operation" />\n<meta name="twitter:description" content="Scott Schulman, the ex-president of Rodale, was said to have clashed with Chairwoman and Chief Executive Maria Rodale over how much money to pump into the company’s fledgling e-commerce site.\nRodale" />\n<meta name="twitter:image" content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=664&amp;h=441&amp;crop=1" />\n<meta property="og:image" content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&amp;strip=all&amp;w=1200" />\n<meta property="og:image:secure_url" content="https://thenypost.files.wordpress.com/2015/10/gettyimages-92659975.jpg?quality=90&#038;strip=all&#038;w=1200" />\n\n<!-- End Jetpack Open Graph Tags -->\n\t\t<meta name=\'parsely-metadata\' content=\'{"post_id":"nypost-9909409"}\' />\n\t\t\t<title>Rodale CEO aims to expand e-commerce operation</title>\n\t\t<link rel="canonical" href="https://nypost.com/2015/10/22/rodale-ceo-aims-to-expand-e-commerce-operation/" />\n\t<script custom-element="amp-analytics" src="https://cdn.ampproject.org/v0/amp-analytics-0.1.js" async></script><script custom-element="amp-iframe" src="https://cdn.ampproject.org/v0/amp-iframe-0.1.js" async></script><script custom-element="amp-ad" src="https://cdn.ampproject.org/v0/a ...
